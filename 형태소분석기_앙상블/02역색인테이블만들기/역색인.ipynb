# %%
import os
import pickle
import pandas as pd
import numpy as np
from collections import Counter
import time
import glob
from sklearn.model_selection import train_test_split
import requests
from bs4 import BeautifulSoup as bs
import tensorflow as tf
from tensorflow import keras
from konlpy.tag import Kkma,Komoran, Okt, Hannanum
okt = Okt()
han = Hannanum()
komoran = Komoran()

# %%
pd.read_excel('vocab_title_table.xlsx').iloc[1,:][3]
# Out:
# '[[1, 1], [2, 1], [3, 1], [5, 1], [8, 1], [11, 2], [12, 2], [13, 1], [14, 1], [15, 1], [16, 1], [24, 1], [25, 1], [29, 1], [30, 1], [34, 1], [37, 1], [38, 1], [45, 1], [49, 1], [50, 1], [51, 1], [52, 1], [53, 1], [54, 1], [56, 1], [57, 1], [60, 1], [61, 1], [64, 1], [67, 1], [72, 1], [77, 1], [78, 1], [83, 1], [84, 1], [88, 1], [96, 1], [98, 1], [100, 1], [108, 1], [111, 1], [115, 1], [118, 1], [119, 1], [120, 1], [121, 1], [125, 1], [127, 1], [129, 1], [131, 1], [134, 1], [135, 1], [136, 1], [139, 1], [140, 1], [142, 1], [143, 1], [144, 1], [148, 1], [150, 1], [155, 1], [160, 1], [163, 1], [167, 1], [168, 1], [170, 1], [172, 1], [173, 1], [174, 1], [176, 1], [179, 1], [180, 1], [181, 1], [182, 1], [185, 1], [186, 1], [187, 1], [188, 1], [191, 1], [197, 1], [199, 1], [200, 1], [201, 1], [202, 1], [205, 1], [207, 1], [212, 1], [225, 1], [229, 1], [232, 1], [236, 1], [240, 1], [241, 1], [243, 1], [244, 1], [246, 1], [247, 1], [250, 1], [252, 1], [256, 1], [258, 1], [260, 1], [261, 1], 
# ...

# %%
dic = [{'12':12},{'33':44}]
sorted(dic, key=lambda x:list(x.values())[0])
# Out:
# [{'12': 12}, {'33': 44}]

# %%
from datetime import datetime as dt
import datetime
da = '2023-01-31'
(dt.now()-dt.strptime(da, '%Y-%m-%d'))
# Out:
# datetime.timedelta(days=12, seconds=44789, microseconds=984002)

# %%
(dt.now()-datetime.timedelta(dt.now().weekday())-dt.strptime(da, '%Y-%m-%d')).days
# Out:
# 8

# %%
dt.now()-datetime.timedelta(dt.now().weekday())
# Out:
# datetime.datetime(2023, 1, 30, 12, 22, 9, 557859)

# %%
dt.today().year
# Out:
# 2023

# %%
dt.strptime(da, '%Y-%m-%d').month
# Out:
# 1

# %%
(dt.today()-datetime.timedelta(dt.today().weekday())-dt.strptime(da, '%Y-%m-%d')).days
# Out:
# 8

# %%
from datetime import datetime as dt
import datetime
da = '2023-02-01'
# (dt.now()-dt.strptime(da, '%Y-%m-%d'))
(dt.today()-datetime.timedelta(dt.today().day-1)-dt.strptime(da, '%Y-%m-%d')).days
# Out:
# 0

# %%
dt.today()
# Out:
# datetime.datetime(2023, 2, 3, 13, 33, 12, 611366)

# %%
da
# Out:
# '2023-01-22'

# %%
dt.today()-datetime.timedelta(dt.today().weekday())
# Out:
# datetime.datetime(2023, 1, 30, 12, 35, 53, 511706)

# %%
dt.today().weekday()
# Out:
# 4

# %% [markdown]
# dt.strptime(da, '%Y-%m-%d')
